# %% [markdown]
# <a href="https://colab.research.google.com/github/viniciusrpb/116319_estruturasdedados/blob/main/Untitled31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Embedding, LSTM, Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.optimizers import Adam

# %%
portuguese_sentences = ["ola mundo", "como voce esta", "bom dia"]
english_sentences = ["hello world", "how are you", "good morning"]

# Add start and end tokens to the English sentences
english_sentences = ["<start> " + sentence + " <end>" for sentence in english_sentences]

# Tokenize the sentences
tokenizer_pt = Tokenizer()
tokenizer_pt.fit_on_texts(portuguese_sentences)
tokenizer_en = Tokenizer(filters='')
tokenizer_en.fit_on_texts(english_sentences)

# Convert sentences to sequences
sequences_pt = tokenizer_pt.texts_to_sequences(portuguese_sentences)
sequences_en = tokenizer_en.texts_to_sequences(english_sentences)

# Pad the sequences
max_len_pt = max([len(seq) for seq in sequences_pt])
max_len_en = max([len(seq) for seq in sequences_en])

sequences_pt = pad_sequences(sequences_pt, maxlen=max_len_pt, padding='post')
sequences_en = pad_sequences(sequences_en, maxlen=max_len_en, padding='post')

# Vocabulary sizes
vocab_size_pt = len(tokenizer_pt.word_index) + 1
vocab_size_en = len(tokenizer_en.word_index) + 1

# %%
# Define the model
embedding_dim = 256
units = 512

# Encoder
encoder_inputs = Input(shape=(max_len_pt,))
encoder_embedding = Embedding(vocab_size_pt, embedding_dim)(encoder_inputs)
encoder_lstm = LSTM(units, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedding)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = tf.keras.Input(shape=(max_len_en,))
decoder_embedding = Embedding(vocab_size_en, embedding_dim)(decoder_inputs)
decoder_lstm = LSTM(units, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense = Dense(vocab_size_en, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
opt = Adam(learning_rate=0.0001)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Prepare the target data
# Shift the target sequences by one to the right
target_data = np.zeros_like(sequences_en)
target_data[:, :-1] = sequences_en[:, 1:]

# Train the model
model.fit([sequences_pt, sequences_en], target_data, batch_size=32, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.1000 - loss: 2.3025 - val_accuracy: 0.2000 - val_loss: 2.3054
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 666ms/step - accuracy: 0.2000 - loss: 2.2979 - val_accuracy: 0.4000 - val_loss: 2.3034
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.4000 - loss: 2.2932 - val_accuracy: 0.4000 - val_loss: 2.3014
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.5000 - loss: 2.2885 - val_accuracy: 0.4000 - val_loss: 2.2994
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.5000 - loss: 2.2838 - val_accuracy: 0.4000 - val_loss: 2.2973
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.5000 - loss: 2.2790 - val_accuracy: 0.4000 - val_loss: 2.2952
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.7000 - loss: 2.2741 - val_accuracy: 0.4000 - val_loss: 2.2930
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.7000 - loss: 2.2692 - val_accuracy: 0.4000 - val_loss: 2.2908
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.8000 - loss: 2.2643 - val_accuracy: 0.4000 - val_loss: 2.2885
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.8000 - loss: 2.2592 - val_accuracy: 0.4000 - val_loss: 2.2862
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.8000 - loss: 2.2540 - val_accuracy: 0.4000 - val_loss: 2.2838
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.8000 - loss: 2.2488 - val_accuracy: 0.4000 - val_loss: 2.2812
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.8000 - loss: 2.2433 - val_accuracy: 0.4000 - val_loss: 2.2786
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.8000 - loss: 2.2378 - val_accuracy: 0.4000 - val_loss: 2.2758
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.8000 - loss: 2.2320 - val_accuracy: 0.4000 - val_loss: 2.2729
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.8000 - loss: 2.2261 - val_accuracy: 0.4000 - val_loss: 2.2699
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.8000 - loss: 2.2199 - val_accuracy: 0.4000 - val_loss: 2.2666
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.8000 - loss: 2.2135 - val_accuracy: 0.4000 - val_loss: 2.2632
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8000 - loss: 2.2069 - val_accuracy: 0.4000 - val_loss: 2.2596
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.8000 - loss: 2.2000 - val_accuracy: 0.4000 - val_loss: 2.2558
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.8000 - loss: 2.1927 - val_accuracy: 0.4000 - val_loss: 2.2517
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.7000 - loss: 2.1851 - val_accuracy: 0.4000 - val_loss: 2.2474
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.7000 - loss: 2.1771 - val_accuracy: 0.4000 - val_loss: 2.2428
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.6000 - loss: 2.1687 - val_accuracy: 0.4000 - val_loss: 2.2378
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.5000 - loss: 2.1599 - val_accuracy: 0.4000 - val_loss: 2.2326
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5000 - loss: 2.1506 - val_accuracy: 0.4000 - val_loss: 2.2269
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.5000 - loss: 2.1407 - val_accuracy: 0.4000 - val_loss: 2.2208
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.5000 - loss: 2.1302 - val_accuracy: 0.4000 - val_loss: 2.2143
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.5000 - loss: 2.1191 - val_accuracy: 0.4000 - val_loss: 2.2072
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.5000 - loss: 2.1072 - val_accuracy: 0.4000 - val_loss: 2.1997
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.5000 - loss: 2.0946 - val_accuracy: 0.4000 - val_loss: 2.1915
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.5000 - loss: 2.0811 - val_accuracy: 0.4000 - val_loss: 2.1827
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.5000 - loss: 2.0667 - val_accuracy: 0.4000 - val_loss: 2.1731
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.5000 - loss: 2.0513 - val_accuracy: 0.4000 - val_loss: 2.1628
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.5000 - loss: 2.0348 - val_accuracy: 0.4000 - val_loss: 2.1517
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.5000 - loss: 2.0172 - val_accuracy: 0.4000 - val_loss: 2.1396
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.5000 - loss: 1.9982 - val_accuracy: 0.4000 - val_loss: 2.1265
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.4000 - loss: 1.9778 - val_accuracy: 0.4000 - val_loss: 2.1123
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.4000 - loss: 1.9560 - val_accuracy: 0.4000 - val_loss: 2.0970
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.4000 - loss: 1.9326 - val_accuracy: 0.4000 - val_loss: 2.0804
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.4000 - loss: 1.9076 - val_accuracy: 0.4000 - val_loss: 2.0624
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.4000 - loss: 1.8808 - val_accuracy: 0.4000 - val_loss: 2.0430
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.4000 - loss: 1.8524 - val_accuracy: 0.4000 - val_loss: 2.0220
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.4000 - loss: 1.8222 - val_accuracy: 0.4000 - val_loss: 1.9994
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.4000 - loss: 1.7906 - val_accuracy: 0.4000 - val_loss: 1.9752
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.4000 - loss: 1.7576 - val_accuracy: 0.4000 - val_loss: 1.9493
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.4000 - loss: 1.7237 - val_accuracy: 0.4000 - val_loss: 1.9218
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.4000 - loss: 1.6895 - val_accuracy: 0.4000 - val_loss: 1.8930
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.4000 - loss: 1.6555 - val_accuracy: 0.4000 - val_loss: 1.8629
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.4000 - loss: 1.6226 - val_accuracy: 0.4000 - val_loss: 1.8322
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.4000 - loss: 1.5917 - val_accuracy: 0.4000 - val_loss: 1.8012
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.3000 - loss: 1.5634 - val_accuracy: 0.4000 - val_loss: 1.7708
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.3000 - loss: 1.5383 - val_accuracy: 0.4000 - val_loss: 1.7416
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.3000 - loss: 1.5166 - val_accuracy: 0.4000 - val_loss: 1.7146
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.3000 - loss: 1.4979 - val_accuracy: 0.4000 - val_loss: 1.6903
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.3000 - loss: 1.4818 - val_accuracy: 0.4000 - val_loss: 1.6692
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.3000 - loss: 1.4671 - val_accuracy: 0.4000 - val_loss: 1.6514
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.3000 - loss: 1.4528 - val_accuracy: 0.4000 - val_loss: 1.6369
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.3000 - loss: 1.4377 - val_accuracy: 0.4000 - val_loss: 1.6256
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.3000 - loss: 1.4212 - val_accuracy: 0.4000 - val_loss: 1.6171
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.3000 - loss: 1.4030 - val_accuracy: 0.4000 - val_loss: 1.6112
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.3000 - loss: 1.3832 - val_accuracy: 0.4000 - val_loss: 1.6075
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.3000 - loss: 1.3623 - val_accuracy: 0.4000 - val_loss: 1.6057
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.3000 - loss: 1.3407 - val_accuracy: 0.4000 - val_loss: 1.6057
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.3000 - loss: 1.3192 - val_accuracy: 0.4000 - val_loss: 1.6071
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.3000 - loss: 1.2982 - val_accuracy: 0.4000 - val_loss: 1.6096
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.4000 - loss: 1.2783 - val_accuracy: 0.4000 - val_loss: 1.6128
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.5000 - loss: 1.2596 - val_accuracy: 0.4000 - val_loss: 1.6165
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.5000 - loss: 1.2422 - val_accuracy: 0.4000 - val_loss: 1.6201
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.5000 - loss: 1.2258 - val_accuracy: 0.4000 - val_loss: 1.6232
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step - accuracy: 0.5000 - loss: 1.2102 - val_accuracy: 0.4000 - val_loss: 1.6255
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.6000 - loss: 1.1946 - val_accuracy: 0.4000 - val_loss: 1.6264
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.6000 - loss: 1.1786 - val_accuracy: 0.4000 - val_loss: 1.6259
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.6000 - loss: 1.1616 - val_accuracy: 0.4000 - val_loss: 1.6238
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.6000 - loss: 1.1434 - val_accuracy: 0.4000 - val_loss: 1.6201
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.6000 - loss: 1.1237 - val_accuracy: 0.4000 - val_loss: 1.6151
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.6000 - loss: 1.1028 - val_accuracy: 0.4000 - val_loss: 1.6091
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.6000 - loss: 1.0811 - val_accuracy: 0.4000 - val_loss: 1.6025
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.5000 - loss: 1.0590 - val_accuracy: 0.4000 - val_loss: 1.5958
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.5000 - loss: 1.0369 - val_accuracy: 0.4000 - val_loss: 1.5895
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.5000 - loss: 1.0152 - val_accuracy: 0.4000 - val_loss: 1.5840
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.5000 - loss: 0.9940 - val_accuracy: 0.4000 - val_loss: 1.5795
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.5000 - loss: 0.9729 - val_accuracy: 0.4000 - val_loss: 1.5764
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.5000 - loss: 0.9517 - val_accuracy: 0.6000 - val_loss: 1.5747
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.5000 - loss: 0.9301 - val_accuracy: 0.6000 - val_loss: 1.5743
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.6000 - loss: 0.9077 - val_accuracy: 0.6000 - val_loss: 1.5753
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.6000 - loss: 0.8849 - val_accuracy: 0.6000 - val_loss: 1.5774
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8000 - loss: 0.8619 - val_accuracy: 0.6000 - val_loss: 1.5803
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8000 - loss: 0.8390 - val_accuracy: 0.6000 - val_loss: 1.5838
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8000 - loss: 0.8165 - val_accuracy: 0.6000 - val_loss: 1.5875
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.8000 - loss: 0.7944 - val_accuracy: 0.6000 - val_loss: 1.5910
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8000 - loss: 0.7726 - val_accuracy: 0.6000 - val_loss: 1.5938
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8000 - loss: 0.7506 - val_accuracy: 0.6000 - val_loss: 1.5958
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.8000 - loss: 0.7283 - val_accuracy: 0.6000 - val_loss: 1.5970
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.8000 - loss: 0.7058 - val_accuracy: 0.6000 - val_loss: 1.5973
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8000 - loss: 0.6836 - val_accuracy: 0.6000 - val_loss: 1.5971
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.8000 - loss: 0.6619 - val_accuracy: 0.6000 - val_loss: 1.5968
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.8000 - loss: 0.6410 - val_accuracy: 0.6000 - val_loss: 1.5967
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.8000 - loss: 0.6204 - val_accuracy: 0.6000 - val_loss: 1.5970
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9000 - loss: 0.6002 - val_accuracy: 0.6000 - val_loss: 1.5981

# %%
# Encoder model
encoder_model = Model(encoder_inputs, encoder_states)

# Decoder model
decoder_state_input_h = Input(shape=(units,))
decoder_state_input_c = Input(shape=(units,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_embedding, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# %%
def decode_sequence(input_seq):
    # Encode the input sequence to get the internal state vectors
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1 with only the start token
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = tokenizer_en.word_index['<start>']

    # Loop for generating the translated sentence
    stop_condition = False
    translated_sentence = ''
    while False:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = tokenizer_en.index_word[sampled_token_index]
        translated_sentence += ' ' + sampled_word

        # Exit condition: either hit max length or find stop token
        if (sampled_word == '<end>' or len(translated_sentence.split()) > max_len_en):
            stop_condition = True

        # Update the target sequence (of length 1)
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update states
        states_value = [h, c]

    return translated_sentence

# Translate a new sentence
input_seq = pad_sequences(tokenizer_pt.texts_to_sequences(["como esta mundo"]), maxlen=max_len_pt, padding='post')
translated_sentence = decode_sequence(input_seq)
print('Translated sentence:', translated_sentence)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# Translated sentence:
